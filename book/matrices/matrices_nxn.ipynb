# %% [markdown]
# # 📐 Matrices $n \times n$: Generalización y Propiedades Fundamentales
#
# En esta lección generalizamos los conceptos de matrices $2 \times 2$ y $3 \times 3$ al caso de **matrices cuadradas de tamaño arbitrario**.
# Comprender las matrices $n \times n$ es fundamental para trabajar en espacios de alta dimensión, resolver sistemas lineales, estudiar transformaciones y analizar estructuras algebraicas.
#
# ---
#
# ## 🔹 1. ¿Qué es una matriz $n \times n$?
#
# Una **matriz cuadrada** de tamaño $n$ es un arreglo de números reales:
#
# \[
# A = (a_{ij}) \in \mathbb{R}^{n \times n}
# \]
#
# - $i$ = índice de fila
# - $j$ = índice de columna
# - $a_{ij} \in \mathbb{R}$
#
# Ejemplo para $n=4$:
#
# \[
# A =
# \begin{pmatrix}
# a_{11} & a_{12} & a_{13} & a_{14} \\
# a_{21} & a_{22} & a_{23} & a_{24} \\
# a_{31} & a_{32} & a_{33} & a_{34} \\
# a_{41} & a_{42} & a_{43} & a_{44}
# \end{pmatrix}
# \]
#
# ---
#
# ## 🔹 2. Operaciones básicas para matrices $n \times n$
#
# ### ➕ Suma de matrices
#
# \[
# (A+B)_{ij} = a_{ij} + b_{ij}
# \]
#
# ### ✖️ Multiplicación por escalar
#
# \[
# (\alpha A)_{ij} = \alpha a_{ij}
# \]
#
# ### ✖️ Multiplicación de matrices
#
# \[
# (AB)_{ij} = \sum_{k=1}^n a_{ik} b_{kj}
# \]
#
# ---
#
# ### 💻 Ejemplo en Python

# %%
import numpy as np

# Matrices 4x4
A = np.array([[1,2,3,4],
              [0,1,0,2],
              [1,0,2,1],
              [3,1,0,1]])

B = np.array([[2,0,1,1],
              [1,3,0,0],
              [0,1,2,1],
              [1,1,1,0]])

print("A + B =\n", A + B)
print("\n2A =\n", 2 * A)
print("\nA * B =\n", A @ B)

# %% [markdown]
# ---
#
# ## 🔹 3. Determinante en dimensión $n$
#
# El determinante es una función:
#
# [
# \det : \mathbb{R}^{n \times n} \to \mathbb{R}
# ]
#
# que extiende las propiedades geométricas vistas en $2\times2$ y $3\times3$.
#
# ### Propiedades claves del determinante:
#
# | Propiedad                   | Interpretación                                       |   |                             |
# | --------------------------- | ---------------------------------------------------- | - | --------------------------- |
# | $\det(A)=0$                 | La transformación aplasta el espacio (no invertible) |   |                             |
# | $\det(A) \neq 0$            | La matriz es invertible                              |   |                             |
# | $                           | \det(A)                                              | $ | Factor de cambio de volumen |
# | $\det(AB) = \det(A)\det(B)$ | Compatibilidad con composición                       |   |                             |
# | $\det(A^T) = \det(A)$       | Invarianza de transpuesta                            |   |                             |
#
# ---
#
# ### 💻 Cálculo computacional

# %%
A = np.random.randint(-5, 5, (5,5))  # matriz 5x5
print("A =\n", A)
print("\ndet(A) =", np.linalg.det(A))

# %% [markdown]
# ---
#
# ## 🔹 4. Rango y núcleos en matrices $n \times n$
#
# El **rango** de una matriz indica cuántas columnas (o filas) son linealmente independientes.
#
# ### Importante:
#
# * Si $\text{rango}(A) = n$, entonces $A$ es invertible.
# * Si $\text{rango}(A) < n$, entonces:
#
#   * $A$ no es invertible
#   * $\ker(A)$ tiene dimensión $>0$
#
# ---
#
# ### 💻 Cálculo en Python

# %%
A = np.array([[1,2,3],[2,4,6],[1,1,1]])  # matriz singular
rango = np.linalg.matrix_rank(A)
print("Rango =", rango)

# %% [markdown]
# ---
#
# ## 🔹 5. Matrices especiales en tamaño $n$
#
# ### 5.1 Matriz identidad
#
# [
# I_n =
# \begin{pmatrix}
# 1 & 0 & \cdots & 0 \
# 0 & 1 & \cdots & 0 \
# \vdots & \vdots & \ddots & \vdots \
# 0 & 0 & \cdots & 1
# \end{pmatrix}
# ]

# %%
I = np.eye(6)
print(I)

# %% [markdown]
# ---
#
# ### 5.2 Matriz diagonal

# %%
D = np.diag([1,2,3,4])
print(D)

# %% [markdown]
# ---
#
# ### 5.3 Matriz triangular superior / inferior

# %%
A = np.triu(np.random.randint(0,5,(4,4)))
print("Triangular superior:\n", A)

B = np.tril(np.random.randint(0,5,(4,4)))
print("Triangular inferior:\n", B)

# %% [markdown]
# ---
#
# ### 5.4 Matriz simétrica
#
# [
# A = A^T
# ]
#
# Propiedad clave:
# sus autovalores son reales.

# %%
M = np.random.randn(4,4)
A = (M + M.T)/2
print("Simétrica:\n", A)

# %% [markdown]
# ---
#
# ### 5.5 Matriz ortogonal
#
# [
# Q^TQ = I
# ]
#
# Representan rotaciones en $\mathbb{R}^n$.

# %%
from numpy.linalg import qr

M = np.random.randn(4,4)
Q, _ = qr(M)
print("Ortogonal Q:\n", Q)
print("Q^T Q =\n", Q.T @ Q)

# %% [markdown]
# ---
#
# ## 🔹 6. Multiplicación matriz–vector
#
# Para **generalizar combinaciones lineales**, toda matriz actúa sobre un vector:
#
# [
# A\mathbf{x} =
# \begin{pmatrix}
# a_{11} x_1 + \cdots + a_{1n} x_n \
# \vdots \
# a_{n1} x_1 + \cdots + a_{nn} x_n
# \end{pmatrix}
# ]
#
# → **La columna 1 de $A$ es la imagen de $e_1$**,
# la columna 2 es la imagen de $e_2$, etc.
#
# ---
#
# ### 💻 Ejemplo

# %%
A = np.array([[1,2,3],
              [0,1,4],
              [5,6,0]])

x = np.array([1,2,3])

print("A x =", A @ x)

# %% [markdown]
# ---
#
# ## 🔹 7. Inversa de una matriz $n \times n$
#
# Existe si y solo si $\det(A) \neq 0$.

# %%
A = np.array([[2,0,1],
              [1,3,0],
              [0,1,2]])

A_inv = np.linalg.inv(A)
print("A^{-1} =\n", A_inv)

# %% [markdown]
# ---
#
# ## 🔹 8. Propiedades fundamentales de las matrices $n \times n$
#
# | Propiedad             | Explicación                               |
# | --------------------- | ----------------------------------------- |
# | Conmutatividad        | **NO** se cumple en general: $AB \neq BA$ |
# | Asociatividad         | $(AB)C = A(BC)$                           |
# | Distributividad       | $A(B+C) = AB + AC$                        |
# | Identidad             | $AI_n = I_nA = A$                         |
# | Invertibilidad        | Depende de $\det(A)$                      |
# | Relación con sistemas | $A\mathbf{x} = b$                         |
#
# ---
#
# ## 🔹 9. Implementaciones útiles

# %%
def matriz_invertible(A):
    return not np.isclose(np.linalg.det(A), 0)

def tipo_matriz(A):
    if np.allclose(A, A.T):
        return "Simétrica"
    if np.allclose(A.T @ A, np.eye(A.shape[0])):
        return "Ortogonal"
    if np.triu(A).shape == A.shape and np.allclose(A, np.triu(A)):
        return "Triangular superior"
    if np.tril(A).shape == A.shape and np.allclose(A, np.tril(A)):
        return "Triangular inferior"
    return "General"

def aplicar(A, X):
    """Aplica A a múltiples vectores X (lista o matriz)."""
    return A @ X

# %% [markdown]
# ---
#
# ## 🧩 10. Ejercicios sugeridos de programación
#
# ### **1. Clasificador de matrices**
#
# Implementa una función que reciba una matriz $n\times n$ y responda:
#
# * ¿Es simétrica?
# * ¿Es diagonal?
# * ¿Es triangular?
# * ¿Es ortogonal?
# * ¿Es invertible?
#
# ---
#
# ### **2. Generador de matrices especiales**
#
# Crea funciones para generar matrices:
#
# * diagonal con valores aleatorios
# * triangular superior/inferior
# * ortogonal usando descomposición QR
# * simétrica aleatoria
#
# ---
#
# ### **3. Visualización de transformaciones en dimensiones altas**
#
# Genera vectores en $\mathbb{R}^n$ (por ejemplo $n=4$) y visualiza sus imágenes proyectándolos a 2D con PCA.
#
# ---
#
# ### **4. Verificación de propiedades de determinante**
#
# Para matrices aleatorias $A$ y $B$:
#
# * verifica $\det(AB) = \det(A)\det(B)$
# * verifica $\det(A^T) = \det(A)$
#
# ---
#
# ### **5. Explorador interactivo de inversas**
#
# Permite al usuario ingresar una matriz y:
#
# * calcular su inversa
# * verificar $AA^{-1}=I$
# * mostrar error numérico
#
# ---
#
# ## 📚 Conclusión
#
# Las matrices $n \times n$ son estructuras universales en álgebra lineal:
# permiten representar transformaciones, resolver sistemas, estudiar simetrías, analizar volúmenes y trabajar con espacios de cualquier dimensión.
#
# > 💬 “La generalidad y el poder de las matrices cuadradas provienen de que pueden actuar como cualquier transformación lineal del espacio.”
#
# ---
#
# ✅ **Siguiente paso:**
# Profundiza en [**Aplicaciones de matrices**](aplicaciones.ipynb): transformaciones lineales, rotaciones, escalas, geometría, y más.
#
# ```
